# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import geoplot
import re
import matplotlib.pyplot as plt
import folium

# %%
data = pd.read_csv('Audiomoth_Global_Score_Count_and_Median.csv')
coords = pd.read_excel('AudioMothPeru_Coordinates.xlsx', engine='openpyxl')

# %%
test_str  = 'GRABADOR-SDZG-AM-10'
test_wwf = 'GRABADOR-WWF-1'

# %%
test_wwf.find('WWF')
# Out:
# 9

# %%
def clean_name(string):
    if string.find('AM') != -1:
        return string[string.find('AM'):]
    else:
        return string[string.find('WWF'):]

# %%
data['Name'] = data.Name.apply(clean_name)

# %%
data
# Out:
#      Name  Count_Above_0.85  Median_Global_Score
# 0    AM-1               770             0.248654
# 1   AM-10               598             0.113959
# 2   AM-11               570             0.072372
# 3   AM-12               111             0.100056
# 4   AM-13                91             0.161304
# 5   AM-14               615             0.062520
# 6   AM-15               754             0.112086
# 7   AM-16               475             0.089241
# 8   AM-17               691             0.134576
# 9   AM-18                 1             0.014899
# 10   AM-2               556             0.079064
# 11  AM-20               593             0.175693
# 12  AM-22               886             0.210056
# 13  AM-23               302             0.031912
# 14  AM-24              1008             0.112833
# 15  AM-25               572             0.086394
# 16  AM-26               623             0.084977
# 17  AM-27               812             0.093379
# 18  AM-29               792             0.149619
# 19   AM-3               693             0.082622
# 20  AM-30               540             0.062385
# 21   AM-4               454             0.053489
# 22   AM-5              1081             0.342143
# 23   AM-6               642             0.135303
# 24   AM-7               556             0.063353
# 25   AM-8               700             0.069205
# 26   AM-9               685             0.148222
# 27  WWF-1               703             0.064495
# 28  WWF-2               954             0.228508
# 29  WWF-3              1185             0.213843
# 30  WWF-4              1098             0.123111
# 31  WWF-5               645             0.090329

# %%
tag_list = []
number_list = []
for name in data.Name:
    split = re.split(r'-', name)
    tag_list.append(split[0])
    number_list.append(split[1])

# %%
data['tag'] = tag_list
data['number'] = number_list

# %%
data['number'] = data.number.apply(int)

# %%
data
# Out:
#      Name  Count_Above_0.85  Median_Global_Score  tag  number
# 0    AM-1               770             0.248654   AM       1
# 1   AM-10               598             0.113959   AM      10
# 2   AM-11               570             0.072372   AM      11
# 3   AM-12               111             0.100056   AM      12
# 4   AM-13                91             0.161304   AM      13
# 5   AM-14               615             0.062520   AM      14
# 6   AM-15               754             0.112086   AM      15
# 7   AM-16               475             0.089241   AM      16
# 8   AM-17               691             0.134576   AM      17
# 9   AM-18                 1             0.014899   AM      18
# 10   AM-2               556             0.079064   AM       2
# 11  AM-20               593             0.175693   AM      20
# 12  AM-22               886             0.210056   AM      22
# 13  AM-23               302             0.031912   AM      23
# 14  AM-24              1008             0.112833   AM      24
# 15  AM-25               572             0.086394   AM      25
# 16  AM-26               623             0.084977   AM      26
# 17  AM-27               812             0.093379   AM      27
# 18  AM-29               792             0.149619   AM      29
# 19   AM-3               693             0.082622   AM       3
# 20  AM-30               540             0.062385   AM      30
# 21   AM-4               454             0.053489   AM       4
# 22   AM-5              1081             0.342143   AM       5
# 23   AM-6               642             0.135303   AM       6
# 24   AM-7               556             0.063353   AM       7
# 25   AM-8               700             0.069205   AM       8
# 26   AM-9               685             0.148222   AM       9
# 27  WWF-1               703             0.064495  WWF       1
# 28  WWF-2               954             0.228508  WWF       2
# 29  WWF-3              1185             0.213843  WWF       3
# 30  WWF-4              1098             0.123111  WWF       4
# 31  WWF-5               645             0.090329  WWF       5

# %%
ams = data.iloc[0:27]
wwfs = data.iloc[27:]

# %%
ams = ams.sort_values('number')

# %%
wwfs
# Out:
#      Name  Count_Above_0.85  Median_Global_Score  tag  number
# 27  WWF-1               703             0.064495  WWF       1
# 28  WWF-2               954             0.228508  WWF       2
# 29  WWF-3              1185             0.213843  WWF       3
# 30  WWF-4              1098             0.123111  WWF       4
# 31  WWF-5               645             0.090329  WWF       5

# %%
sorted_data.reset_index(drop=True, inplace=True)
coords.reset_index(drop=True, inplace=True)

# %%
sorted_data = pd.concat([ams, wwfs])

# %%
sorted_data
# Out:
#      Name  Count_Above_0.85  Median_Global_Score  tag  number
# 0    AM-1               770             0.248654   AM       1
# 10   AM-2               556             0.079064   AM       2
# 19   AM-3               693             0.082622   AM       3
# 21   AM-4               454             0.053489   AM       4
# 22   AM-5              1081             0.342143   AM       5
# 23   AM-6               642             0.135303   AM       6
# 24   AM-7               556             0.063353   AM       7
# 25   AM-8               700             0.069205   AM       8
# 26   AM-9               685             0.148222   AM       9
# 1   AM-10               598             0.113959   AM      10
# 2   AM-11               570             0.072372   AM      11
# 3   AM-12               111             0.100056   AM      12
# 4   AM-13                91             0.161304   AM      13
# 5   AM-14               615             0.062520   AM      14
# 6   AM-15               754             0.112086   AM      15
# 7   AM-16               475             0.089241   AM      16
# 8   AM-17               691             0.134576   AM      17
# 9   AM-18                 1             0.014899   AM      18
# 11  AM-20               593             0.175693   AM      20
# 12  AM-22               886             0.210056   AM      22
# 13  AM-23               302             0.031912   AM      23
# 14  AM-24              1008             0.112833   AM      24
# 15  AM-25               572             0.086394   AM      25
# 16  AM-26               623             0.084977   AM      26
# 17  AM-27               812             0.093379   AM      27
# 18  AM-29               792             0.149619   AM      29
# 20  AM-30               540             0.062385   AM      30
# 27  WWF-1               703             0.064495  WWF       1
# 28  WWF-2               954             0.228508  WWF       2
# 29  WWF-3              1185             0.213843  WWF       3
# 30  WWF-4              1098             0.123111  WWF       4
# 31  WWF-5               645             0.090329  WWF       5

# %%
for i in ['AM 19', 'AM 21', 'AM 28']:
    coords = coords[coords.Code != i]

# %%
sorted_data.reset_index(drop=True, inplace=True)
coords.reset_index(drop=True, inplace=True)

# %%
both = pd.concat([coords, sorted_data], axis=1)

# %%
both
# Out:
#         Code       X        Y       Date      Time Road.Trail        Lat  \
# 0       AM 1  371179  8756251 2019-06-16       NaN       Road -11.248805
# 1       AM 2  387647  8771172 2019-06-15  09:53:00       Road -11.114443
# 2       AM 3  364248  8754481 2019-06-16  10:11:00       Road -11.264551
# 3       AM 4  387629  8713988 2019-06-20  13:06:00       Road -11.631518
# 4       AM 5  413088  8754456 2019-06-18  12:25:00       Road -11.266313
# 28  425911  8729594 2019-06-27  11:05:00       Road -11.491435 -69.679334
# 29  400214  8708928 2019-06-22  10:23:00       Road -11.677663 -69.915543
# 30  431893  8726116 2019-06-22  17:48:17       Road -11.523010 -69.624556
# 31  432174  8726302 2019-06-27  13:15:00       Road -11.521333 -69.621975
#
#      Name  Count_Above_0.85  Median_Global_Score
# 0    AM-1               770             0.248654
# 1    AM-2               556             0.079064
# 2    AM-3               693             0.082622
# 3    AM-4               454             0.053489
# 4    AM-5              1081             0.342143
# 5    AM-6               642             0.135303
# 6    AM-7               556             0.063353
# 7    AM-8               700             0.069205
# 8    AM-9               685             0.148222
# 9   AM-10               598             0.113959
# 10  AM-11               570             0.072372
# 11  AM-12               111             0.100056
# 12  AM-13                91             0.161304
# 13  AM-14               615             0.062520
# 14  AM-15               754             0.112086
# 15  AM-16               475             0.089241
# 16  AM-17               691             0.134576
# 17  AM-18                 1             0.014899
# 18  AM-20               593             0.175693
# 19  AM-22               886             0.210056
# 20  AM-23               302             0.031912
# 21  AM-24              1008             0.112833
# 22  AM-25               572             0.086394
# 23  AM-26               623             0.084977
# 24  AM-27               812             0.093379
# 25  AM-29               792             0.149619
# 26  AM-30               540             0.062385
# 27  WWF-1               703             0.064495
# 28  WWF-2               954             0.228508
# 29  WWF-3              1185             0.213843
# 30  WWF-4              1098             0.123111
# 31  WWF-5               645             0.090329

# %%
for
# Out:
# ['naturalearth_cities', 'naturalearth_lowres', 'nybb']

# %%
world_filepath = gpd.datasets.get_path('naturalearth_lowres')
world = gpd.read_file(world_filepath)
peru = world[world.name == 'Peru' and 'Bolivia' and 'Brazil']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-133-8085909141a6> in <module>
#       1 world_filepath = gpd.datasets.get_path('naturalearth_lowres')
#       2 world = gpd.read_file(world_filepath)
# ----> 3 peru = world[world.name == 'Peru' and 'Bolivia' and 'Brazil']
#
# ~/opt/anaconda3/envs/geo_env/lib/python3.9/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1440     @final
#    1441     def __nonzero__(self):
# -> 1442         raise ValueError(
#    1443             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1444             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
three_map = pd.DataFrame()
for i in ['Peru', 'Bolivia', 'Brazil']:
    three_map = pd.concat([three_map, world[world.name == i]])

# %%
three_map
# Out:
#       pop_est      continent     name iso_a3  gdp_md_est  \
# 31   31036656  South America     Peru    PER    410400.0
# 30   11138234  South America  Bolivia    BOL     78350.0
# 29  207353391  South America   Brazil    BRA   3081000.0
#
#                                              geometry
# 31  POLYGON ((-69.89364 -4.29819, -70.79477 -4.251...
# 30  POLYGON ((-69.52968 -10.95173, -68.78616 -11.0...
# 29  POLYGON ((-53.37366 -33.76838, -53.65054 -33.2...

# %%
geoplot.polyplot(three_map, figsize=(8, 4))
# Out:
# <AxesSubplot:>

# %%
plt.scatter(both.Long, both.Lat, s=both.Median_Global_Score * 3000, alpha=0.2)
plt.savefig('Bubble_median.png')

# %%
plt.scatter(both.Long, both.Lat, s=both['Count_Above_0.85'] * .3, alpha=0.2)
plt.savefig('Bubble_count.png')

# %%
m = folium.Map(location=[-11.2900641, -70.011344], tiles="Stamen Terrain", zoom_start=9)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_17d6383cffa4406e824ebd2992a438b8%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_17d6383cffa4406e824ebd2992a438b8%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_17d6383cffa4406e824ebd2992a438b8%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_17d6383cffa4406e824ebd2992a438b8%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B-11.2900641%2C%20-70.011344%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
m_median = folium.Map(location=[-11.2900641, -70.011344], tiles="Stamen Terrain", zoom_start=9)
for i in range(0,len(both)):
   folium.CircleMarker(
      location=[both.iloc[i]['Lat'], both.iloc[i]['Long']],
      popup=data.iloc[i]['Name'],
      radius=float((both.iloc[i]['Median_Global_Score'])) * 100,
      color='red',
      fill=True,
      fill_color='red'
   ).add_to(m_median)
m_median
#m_median.save('median_bubble.html')

# %%
m_count = folium.Map(location=[-11.2900641, -70.011344], tiles="Stamen Terrain", zoom_start=9)
for i in range(0,len(both)):
   folium.CircleMarker(
      location=[both.iloc[i]['Lat'], both.iloc[i]['Long']],
      popup=data.iloc[i]['Name'],
      radius=float((both.iloc[i]['Count_Above_0.85'])) * .02,
      color='red',
      fill=True,
      fill_color='red'
   ).add_to(m_count)
m_count
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_835599546ba841e6bd0374bca8744614%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_835599546ba841e6bd0374bca8744614%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_835599546ba841e6bd0374bca8744614%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_835599546ba841e6bd0374bca8744614%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B-11.2900641%2C%20-70.011344%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
both.head()
# Out:
#         X        Y       Date      Time Road.Trail        Lat       Long  \
# 0  371179  8756251 2019-06-16       NaN       Road -11.248805 -70.180129
# 1  387647  8771172 2019-06-15  09:53:00       Road -11.114443 -70.028808
# 2  364248  8754481 2019-06-16  10:11:00       Road -11.264551 -70.243683
# 3  387629  8713988 2019-06-20  13:06:00       Road -11.631518 -70.030831
# 4  413088  8754456 2019-06-18  12:25:00       Road -11.266313 -69.796278
#
#    Name  Count_Above_0.85  Median_Global_Score
# 0  AM-1               770             0.248654
# 1  AM-2               556             0.079064
# 2  AM-3               693             0.082622
# 3  AM-4               454             0.053489
# 4  AM-5              1081             0.342143

# %%
mean = 0
std = .005 
num_samples = 1000
samples = np.random.normal(mean, std, size=num_samples)
plt.plot(samples)
plt.show()

# %%
def fudge_coords(coord):
    offset = np.random.normal(0, .005)
    new_coord = coord + offset
    return new_coord

# %%
new_Lat = both.Lat.apply(fudge_coords)
new_Long = both.Long.apply(fudge_coords)

# %%
both
# Out:
#          X        Y       Date      Time Road.Trail        Lat       Long  \
# 0   371179  8756251 2019-06-16       NaN       Road -11.249394 -70.175812
# 1   387647  8771172 2019-06-15  09:53:00       Road -11.117564 -70.025542
# 2   364248  8754481 2019-06-16  10:11:00       Road -11.263070 -70.241817
# 3   387629  8713988 2019-06-20  13:06:00       Road -11.626435 -70.025273
# 4   413088  8754456 2019-06-18  12:25:00       Road -11.268149 -69.789778
# 5   372473  8759585 2019-06-14  16:15:00   Off-Road -11.224890 -70.166682
# 6   367470  8761989 2019-06-14  11:58:00       Road -11.202386 -70.214966
# 7   392448  8765495 2019-06-15  12:07:00       Road -11.177148 -69.984584
# 8   374330  8754231 2019-06-15  09:49:00       Road -11.273757 -70.153973
